# %% [markdown]
# # Data files

# %%
ls /data/DataFest2017
# Out:
# data.txt  data.zip  dest.txt  dest.zip

# %%
wc /data/DataFest2017/data.txt
# Out:
#   10884540  353827794 2103515031 /data/DataFest2017/data.txt

# %%
wc /data/DataFest2017/dest.txt
# Out:
#     36408   5420074 101528144 /data/DataFest2017/dest.txt

# %% [markdown]
# # View data

# %%
head -n 1 /data/DataFest2017/data.txt
# Out:
# date_time	site_name	user_location_country	user_location_region	user_location_city	user_location_latitude	user_location_longitude	orig_destination_distance	user_id	is_mobile	is_package	channel	srch_ci	srch_co	srch_adults_cnt	srch_children_cnt	srch_rm_cnt	srch_destination_id	hotel_country	is_booking	hotel_id	prop_is_branded	prop_starrating	distance_band	hist_price_band	popularity_band	cnt

# %%
head -n 2 /data/DataFest2017/data.txt
# Out:
# date_time	site_name	user_location_country	user_location_region	user_location_city	user_location_latitude	user_location_longitude	orig_destination_distance	user_id	is_mobile	is_package	channel	srch_ci	srch_co	srch_adults_cnt	srch_children_cnt	srch_rm_cnt	srch_destination_id	hotel_country	is_booking	hotel_id	prop_is_branded	prop_starrating	distance_band	hist_price_band	popularity_band	cnt
# 2015-09-03 16:37:00	EXPEDIA.COM	UNITED STATES OF AMERICA	CA	BRENTWOOD	37.92381	-121.69622	5539.583	-2147479371	1	0	324	2016-05-19	2016-05-23	2	0	1	24802975	FRANCE	0	17366540	0	3.0	M	L	VH	1

# %%
head /data/DataFest2017/data.txt
# Out:
# date_time	site_name	user_location_country	user_location_region	user_location_city	user_location_latitude	user_location_longitude	orig_destination_distance	user_id	is_mobile	is_package	channel	srch_ci	srch_co	srch_adults_cnt	srch_children_cnt	srch_rm_cnt	srch_destination_id	hotel_country	is_booking	hotel_id	prop_is_branded	prop_starrating	distance_band	hist_price_band	popularity_band	cnt
# 2015-09-03 16:37:00	EXPEDIA.COM	UNITED STATES OF AMERICA	CA	BRENTWOOD	37.92381	-121.69622	5539.583	-2147479371	1	0	324	2016-05-19	2016-05-23	2	0	1	24802975	FRANCE	0	17366540	0	3.0	M	L	VH	1
# 2015-09-21 22:47:00	EXPEDIA.COM	UNITED STATES OF AMERICA	CA	BRENTWOOD	37.92381	-121.69622	5873.028	-2147479371	1	0	324	2016-05-12	2016-05-15	2	0	1	187569808	FRANCE	0	133800525	1	4.0	C	M	VH	2
# 2015-11-15 21:15:00	EXPEDIA.COM	UNITED STATES OF AMERICA	CA	BRENTWOOD	37.92381	-121.69622	5329.1407	-2147479371	1	0	541	2015-11-29	2015-11-30	2	0	1	5526772	UNITED KINGDOM	0	439889	1	4.0	M	H	VH	1
# ...

# %% [markdown]
# -------

# %%
head /data/DataFest2017/dest.txt
# Out:
# srch_destination_id	srch_destination_name	srch_destination_type_id	srch_destination_latitude	srch_destination_longitude	popular_activity_adventure	popular_attraction_aquarium	popular_historical_archaeology	popular_architecture_architecture	popular_cultural_art	popular_social_bars	popular_activity_baseball	popular_activity_basketball	popular_naturalfeature_beach	popular_food_beer	popular_activity_biking	popular_activity_birdwatching	popular_activity_boating	popular_lifestyle_budget	popular_field_business	popular_social_cafes	popular_activity_camping	popular_entertainment_casino	popular_architecture_castle	popular_architecture_cathedral	popular_activity_caveexploring	popular_tourism_chinatown	popular_architecture_churches	popular_food_cocktails	popular_food_coffee	popular_activity_conferences	popular_activity_coralreefs	popular_naturalfeature_countryside	popular_activity_crosscountryskiing	popular_cultural_culture	popular_activity_dancing	popular_naturalfeature_desert	popular_activity_
# ...
